# %%
from data_loader import (\n    load_books,\n    load_users,\n    load_ratings,\n    load_all_data,\n    load_merged_data,\n    create_user_item_matrix,\n    split_ratings,\n    check_data,\n)\n\n# Load the three datasets\nbooks, users, ratings = load_all_data()\n\n# Combine all data into one table\nmerged_data = load_merged_data()\n\n# Create matrix for collaborative filtering\nuser_item_matrix = create_user_item_matrix()\n\n# Split ratings for model testing\ntrain_ratings, test_ratings = split_ratings()\n\n# Show simple dataset summary\ncheck_data()
